# %%
import utils.DatasetAccess as db_access

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
connection = db_access.get_connection()

# %%
scores = db_access.get_score_from_r_squared_range(connection, 0.999, 1, model_id=3, forecasted_point=10)

# %%
scores.head(), scores.shape
# Out:
# (     id  model_id  r_squared forecasted_points    data_to  data_from
#  0  8442         3   0.999056                10 2021-04-01 2018-04-01
#  1  8571         3   0.999031                10 2021-04-01 2018-04-01
#  2  8715         3   0.999209                10 2021-04-01 2018-04-01
#  3  8719         3   0.999883                10 2021-04-01 2018-04-01
#  4  8755         3   0.999685                10 2021-04-01 2018-04-01,
#  (13, 6))

# %%
def get_graph_for_row(row=None, id=None):
    if not row is None:
        graph = db_access.get_graph_for_id(row['id'], connection)

        graph = graph.reset_index()#.replace(np.nan, 0)#.plot(x='index', y=['y', 'y_hat'], kind = 'scatter')
        # ax = graph.plot(x="index", y="y", kind="scatter")
        graph.plot(x='index', y=['y', 'y_hat'])
        plt.show()
        print(row['id'], row['r_squared'])
    else:
        graph = db_access.get_graph_for_id(id, connection)

        graph = graph.reset_index()#.replace(np.nan, 0)#.plot(x='index', y=['y', 'y_hat'], kind = 'scatter')
        # ax = graph.plot(x="index", y="y", kind="scatter")
        graph.plot(x='index', y=['y', 'y_hat'])
        plt.show()
        print(id)

# %%
get_graph_for_row(row=scores.iloc[0])
get_graph_for_row(row=scores.iloc[1])
get_graph_for_row(row=scores.iloc[2])
get_graph_for_row(row=scores.iloc[3])
get_graph_for_row(row=scores.iloc[4])
get_graph_for_row(row=scores.iloc[5])
get_graph_for_row(row=scores.iloc[6])
get_graph_for_row(row=scores.iloc[7])
get_graph_for_row(row=scores.iloc[8])
get_graph_for_row(row=scores.iloc[9])
get_graph_for_row(row=scores.iloc[10])
get_graph_for_row(row=scores.iloc[11])
get_graph_for_row(row=scores.iloc[12])
# Out:
# 8442 0.999055896429365
# 8571 0.9990314020128008
# 8715 0.9992088768089114
# 8719 0.9998827769801361
# 8755 0.9996851558155379
# 8952 0.9997779444914933
# 8967 0.9997050297644626
# 9053 0.9997429945668127
# 9055 0.9993940409357964
# 9076 0.99926913643991
# 9082 0.9993188989407927
# 9255 0.9993421911103652
# 9258 0.9995606226692183

# %%
for index, row in scores.iterrows():
    get_graph_for_row(row)

    

# df.plot(x="X", y="B", kind="bar", ax=ax, color="C2")
# df.plot(x="X", y="C", kind="bar", ax=ax, color="C3")
    # print(graph.shape)
# Out:
# 8442 0.999055896429365
# 8571 0.9990314020128008
# 8715 0.9992088768089114
# 8719 0.9998827769801361
# 8755 0.9996851558155379
# 8952 0.9997779444914933
# 8967 0.9997050297644626
# 9053 0.9997429945668127
# 9055 0.9993940409357964
# 9076 0.99926913643991
# 9082 0.9993188989407927
# 9255 0.9993421911103652
# 9258 0.9995606226692183
